# %%
import pandas as pd
df = pd.read_excel('./dataupdate.xlsx','weather')
df
# Out:
#           Day  Temperature  WindSpeed    Event
# 0  2020-12-01           30          9  แดดร้อน
# 1  2020-12-02           28          8   เมฆมาก
# 2  2020-12-03           27          4     ฝนตก
# 3  2020-12-04           19          3  แดดร้อน
# 4  2020-12-05           20          5   เมฆมาก
# 5  2020-12-06           25          6     ฝนตก
# 6  2020-12-07           36          4     ฝนตก
# 7  2020-12-08           28          6     ฝนตก
# 8  2020-12-09           17          5   เมฆมาก
# 9  2020-12-10           24          6  แดดร้อน
# 10 2020-12-11           26          4     ฝนตก
# 11 2020-12-12           27          9  แดดร้อน
# 12 2020-12-13           30          2  แดดร้อน
# 13 2020-12-14           31          5   เมฆมาก
# 14 2020-12-15           28          4  แดดร้อน
# 15 2020-12-16           27          7  แดดร้อน
# 16 2020-12-17           20          8     ฝนตก
# 17 2020-12-18           18          5     ฝนตก
# 18 2020-12-19           25          7  แดดร้อน
# ...

# %%
df.head() # อ่านข้อมูล 5 แถวแรก
df.head(10)# อ่านข้อมูล n แถวแรก
# Out:
#          Day  Temperature  WindSpeed    Event
# 0 2020-12-01           30          9  แดดร้อน
# 1 2020-12-02           28          8   เมฆมาก
# 2 2020-12-03           27          4     ฝนตก
# 3 2020-12-04           19          3  แดดร้อน
# 4 2020-12-05           20          5   เมฆมาก
# 5 2020-12-06           25          6     ฝนตก
# 6 2020-12-07           36          4     ฝนตก
# 7 2020-12-08           28          6     ฝนตก
# 8 2020-12-09           17          5   เมฆมาก
# 9 2020-12-10           24          6  แดดร้อน

# %%
df.tail() # อ่านข้อมูล 5 แถวสุดท้าย
df.tail(10) # อ่านข้อมูล n แถวสุดท้าย
# Out:
#           Day  Temperature  WindSpeed    Event
# 20 2020-12-21           25          5   เมฆมาก
# 21 2020-12-22           38          2   เมฆมาก
# 22 2020-12-23           34          3     ฝนตก
# 23 2020-12-24           29          4     ฝนตก
# 24 2020-12-25           34          5  แดดร้อน
# 25 2020-12-26           25          8     ฝนตก
# 26 2020-12-27           28          9   เมฆมาก
# 27 2020-12-28           30          2   เมฆมาก
# 28 2020-12-29           31          1     ฝนตก
# 29 2020-12-30           35          2     ฝนตก

# %%
df.sample() # สุ่ม 1 ค่า
df.sample(5) # สุ่ม n ค่า
# Out:
#           Day  Temperature  WindSpeed    Event
# 27 2020-12-28           30          2   เมฆมาก
# 24 2020-12-25           34          5  แดดร้อน
# 29 2020-12-30           35          2     ฝนตก
# 16 2020-12-17           20          8     ฝนตก
# 21 2020-12-22           38          2   เมฆมาก

# %%
'''
จำนวนข้อมูล
ค่าเฉลี่ย
ส่วนเบี่ยงเบนมาตรฐาน
น้อยสุด
-
-
-
มากสด
'''
df.describe()
# Out:
#        Temperature  WindSpeed
# count    30.000000  30.000000
# mean     27.433333   5.066667
# std       5.237026   2.288402
# min      17.000000   1.000000
# 25%      25.000000   4.000000
# 50%      28.000000   5.000000
# 75%      30.000000   6.750000
# max      38.000000   9.000000

# %%
# ข้อมูลกี่แถว กี่คอลัม
df.shape
# Out:
# (30, 4)

# %%
# columns
df.columns
# Out:
# Index(['Day', 'Temperature', 'WindSpeed', 'Event'], dtype='object')

# %%
df = pd.read_excel('./dataupdate.xlsx','weather',index_col='Day')
df.values
# Out:
# array([[30, 9, 'แดดร้อน'],
#        [28, 8, 'เมฆมาก'],
#        [27, 4, 'ฝนตก'],
#        [19, 3, 'แดดร้อน'],
#        [20, 5, 'เมฆมาก'],
#        [25, 6, 'ฝนตก'],
#        [36, 4, 'ฝนตก'],
#        [28, 6, 'ฝนตก'],
#        [17, 5, 'เมฆมาก'],
#        [24, 6, 'แดดร้อน'],
#        [26, 4, 'ฝนตก'],
#        [27, 9, 'แดดร้อน'],
#        [30, 2, 'แดดร้อน'],
#        [31, 5, 'เมฆมาก'],
#        [28, 4, 'แดดร้อน'],
#        [27, 7, 'แดดร้อน'],
#        [20, 8, 'ฝนตก'],
#        [18, 5, 'ฝนตก'],
#        [25, 7, 'แดดร้อน'],
#        [28, 4, 'เมฆมาก'],
#        [25, 5, 'เมฆมาก'],
#        [38, 2, 'เมฆมาก'],
#        [34, 3, 'ฝนตก'],
#        [29, 4, 'ฝนตก'],
#        [34, 5, 'แดดร้อน'],
#        [25, 8, 'ฝนตก'],
#        [28, 9, 'เมฆมาก'],
#        [30, 2, 'เมฆมาก'],
#        [31, 1, 'ฝนตก'],
#        [35, 2, 'ฝนตก']], dtype=object)
